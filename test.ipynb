# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
s0_rewards = np.load('experiments/sasrec_0/rewards.npy')
s1_rewards = np.load('experiments/sasrec_1/rewards.npy')
s2_rewards = np.load('experiments/sasrec_2/rewards.npy')
ssknn_rewards = np.load('experiments/ssknn/rewards.npy')

print(f'sasrec 0 avg reward: {s0_rewards.mean()}')
print(f'sasrec 1 avg reward: {s1_rewards.mean()}')
print(f'sasrec 2 avg reward: {s2_rewards.mean()}')
print(f'ssknn    avg reward: {ssknn_rewards.mean()}')
# Out:
# sasrec 0 avg reward: 0.4793885652227537
# sasrec 1 avg reward: 0.3493756552758234
# sasrec 2 avg reward: 0.14380742993054474
# ssknn    avg reward: 0.35262530085636673

# %%
df = pd.read_csv('experiments/nm_25/log.csv')
df
# Out:
#          userid  movieid  timestamp
# 0             0      841          0
# 1             0     2921          1
# 2             0     2588          3
# 3             0     2939          4
# 4             0     2930          5
# ...         ...      ...        ...
# 1018142    6039     3058        211
# 1018143    6039     3325        213
# 1018144    6039     3539        214
# 1018145    6039     3373        215
# 1018146    6039     3176        216
#
# [1018147 rows x 3 columns]

# %%
df['order'] = df.groupby('userid')['timestamp'].transform(lambda x: np.argsort(x))
df
# Out:
#          userid  movieid  timestamp  order
# 0             0      841          0      0
# 1             0     2921          1      1
# 2             0     2588          3      2
# 3             0     2939          4      3
# 4             0     2930          5      4
# ...         ...      ...        ...    ...
# 1018142    6039     3058        211    186
# 1018143    6039     3325        213    187
# 1018144    6039     3539        214    188
# 1018145    6039     3373        215    189
# 1018146    6039     3176        216    190
#
# [1018147 rows x 4 columns]

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 10]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 20]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 30]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 40]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 50]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 60]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 70]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 80]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 90]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 100]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 110]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 120]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 130]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 140]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 150]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 160]['movieid'], bins=100)

# %%
plt.figure(figsize=(16, 9))
_ = plt.hist(df[df['order'] == 170]['movieid'], bins=100)
